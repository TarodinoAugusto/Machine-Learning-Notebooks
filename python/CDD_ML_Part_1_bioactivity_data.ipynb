# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.12/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.3.3)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.7.22)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (26.1.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (26.1.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.11.3)
# Requirement already satisfied: url-normalize>=2.0 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.16.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for schistossoma mansoni
target = new_client.target
target_query = target.search('schistosoma mansoni')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                 organism  \
# 0                []      Schistosoma mansoni
# 1                []    Schistosoma japonicum
# 2                []  Schistosoma haematobium
# 3                []      Schistosoma mansoni
# 4                []      Schistosoma mansoni
# 5                []      Schistosoma mansoni
# 6                []      Schistosoma mansoni
# 7                []      Schistosoma mansoni
# 8                []      Schistosoma mansoni
# 9                []      Schistosoma mansoni
# 10               []      Schistosoma mansoni
# 11               []      Schistosoma mansoni
# 12               []      Schistosoma mansoni
# 13               []      Schistosoma mansoni
#
#                                             pref_name  score  \
# 0                                 Schistosoma mansoni   36.0
# 1                               Schistosoma japonicum   17.0
# 2                             Schistosoma haematobium   17.0
# 3                   Thioredoxin glutathione reductase   11.0
# 4                              Thioredoxin peroxidase   11.0
# 5    Voltage-activated calcium channel beta 1 subunit   11.0
# 6    Voltage-activated calcium channel beta 2 subunit   11.0
# 7                               Histone deacetylase 8   11.0
# 8                   NAD-dependent protein deacetylase   11.0
# 9   Dihydroorotate dehydrogenase (quinone), mitoch...   11.0
# 10                           ATP-diphosphohydrolase 1   11.0
# 11                             Cathepsin B1 isotype 1   11.0
# 12                            Venus kinase receptor 2   11.0
# 13                                                DNA   10.0
#
#     species_group_flag target_chembl_id  \
# 0                False     CHEMBL612893
# 1                False     CHEMBL612644
# 2                False    CHEMBL4296598
# 3                False       CHEMBL6110
# 4                False    CHEMBL1293279
# 5                False    CHEMBL2363079
# 6                False    CHEMBL2363080
# 7                False    CHEMBL3797017
# 8                False    CHEMBL4523517
# 9                False    CHEMBL4523950
# 10               False    CHEMBL4879549
# 11               False    CHEMBL4888438
# 12               False    CHEMBL5169215
# 13               False    CHEMBL2366043
#
#                                     target_components     target_type  tax_id
# 0                                                  []        ORGANISM    6183
# 1                                                  []        ORGANISM    6182
# 2                                                  []        ORGANISM    6185
# 3   [{'accession': 'Q962Y6', 'component_descriptio...  SINGLE PROTEIN    6183
# 4   [{'accession': 'O97161', 'component_descriptio...  SINGLE PROTEIN    6183
# 5   [{'accession': 'Q95US7', 'component_descriptio...  SINGLE PROTEIN    6183
# 6   [{'accession': 'Q962H3', 'component_descriptio...  SINGLE PROTEIN    6183
# 7   [{'accession': 'A5H660', 'component_descriptio...  SINGLE PROTEIN    6183
# 8   [{'accession': 'T1VXA1', 'component_descriptio...  SINGLE PROTEIN    6183
# 9   [{'accession': 'G4VFD7', 'component_descriptio...  SINGLE PROTEIN    6183
# 10  [{'accession': 'Q7YTA4', 'component_descriptio...  SINGLE PROTEIN    6183
# 11  [{'accession': 'Q8MNY2', 'component_descriptio...  SINGLE PROTEIN    6183
# 12  [{'accession': 'D5JEH1', 'component_descriptio...  SINGLE PROTEIN    6183
# 13                                                 []    NUCLEIC-ACID    6183

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[3]
selected_target
# Out:
# 'CHEMBL6110'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      2931445                  []
# 1        None             None      2931446                  []
# 2        None             None      2931447                  []
#
#   assay_chembl_id                      assay_description assay_type  \
# 0   CHEMBL1048278  Inhibition of Schistosoma mansoni TGR          B
# 1   CHEMBL1048278  Inhibition of Schistosoma mansoni TGR          B
# 2   CHEMBL1048278  Inhibition of Schistosoma mansoni TGR          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
#        target_organism                   target_pref_name target_tax_id  \
# 0  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 1  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 2  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
#
#   text_value  toid  type units    uo_units upper_value value
# 0       None  None  IC50    uM  UO_0000065        None  0.35
# 1       None  None  IC50    uM  UO_0000065        None   0.4
# 2       None  None  IC50    uM  UO_0000065        None  0.48
#
# [3 rows x 47 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data2’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# -rw------- 1 root root 34347 Aug 20 13:49 '/content/gdrive/My Drive/Colab Notebooks/data'

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,modality,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,2931445,[],CHEMBL1048278,Inhibition of Schistosoma mansoni TGR,B,,,BAO_0000190,BAO_0000357,single protein format,N#Cc1c(-c2csc(-c3no[n+]([O-])c3C#N)c2)no[n+]1[O-],,,CHEMBL1155233,J Med Chem,2009,"{'bei': '21.36', 'le': '0.42', 'lle': '6.39', 'sei': '4.21'}",,CHEMBL576624,,CHEMBL576624,6.46,0,http://www.openphacts.org/units/Nanomolar,853210,=,1,1,=,,IC50,nM,,350.0,CHEMBL6110,Schistosoma mansoni,Thioredoxin glutathione reductase,6183,,,IC50,uM,UO_0000065,,0.35
# ,,2931446,[],CHEMBL1048278,Inhibition of Schistosoma mansoni TGR,B,,,BAO_0000190,BAO_0000357,single protein format,N#Cc1c(-c2ccc(-c3no[n+]([O-])c3C#N)s2)no[n+]1[O-],,,CHEMBL1155233,J Med Chem,2009,"{'bei': '21.17', 'le': '0.42', 'lle': '6.33', 'sei': '4.17'}",,CHEMBL569420,,CHEMBL569420,6.40,0,http://www.openphacts.org/units/Nanomolar,853342,=,1,1,=,,IC50,nM,,400.0,CHEMBL6110,Schistosoma mansoni,Thioredoxin glutathione reductase,6183,,,IC50,uM,UO_0000065,,0.4
# ,,2931447,[],CHEMBL1048278,Inhibition of Schistosoma mansoni TGR,B,,,BAO_0000190,BAO_0000357,single protein format,N#Cc1c(-c2cc(F)cc(-c3no[n+]([O-])c3C#N)c2)no[n+]1[O-],,,CHEMBL1155233,J Med Chem,2009,"{'bei': '20.11', 'le': '0.38', 'lle': '6.17', 'sei': '4.12'}",,CHEMBL570121,,CHEMBL570121,6.32,0,http://www.openphacts.org/units/Nanomolar,853334,=,1,1,=,,IC50,nM,,480.0,CHEMBL6110,Schistosoma mansoni,Thioredoxin glutathione reductase,6183,,,IC50,uM,UO_0000065,,0.48
# ,,2931448,[],CHEMBL1048278,Inhibition of Schistosoma mansoni TGR,B,,,BAO_0000190,BAO_0000357,single protein format,N#Cc1c(-c2ccc(-c3no[n+]([O-])c3C#N)cc2)no[n+]1[O-],,,CHEMBL1155233,J Med Chem,2009,"{'bei': '20.26', 'le': '0.37', 'lle': '5.99', 'sei': '3.91'}",,CHEMBL582970,,CHEMBL582970,6.00,0,http://www.openphacts.org/units/Nanomolar,853333,=,1,1,=,,IC50,nM,,1000.0,CHEMBL6110,Schistosoma mansoni,Thioredoxin glutathione reductase,6183,,,IC50,uM,UO_0000065,,1.0
# ,,2931449,[],CHEMBL1048278,Inhibition of Schistosoma mansoni TGR,B,,,BAO_0000190,BAO_0000357,single protein format,N#Cc1c(-c2cccc(-c3no[n+]([O-])c3C#N)c2)no[n+]1[O-],,,CHEMBL1155233,J Med Chem,2009,"{'bei': '18.42', 'le': '0.34', 'lle': '5.45', 'sei': '3.55'}",,CHEMBL575013,,CHEMBL575013,5.46,0,http://www.openphacts.org/units/Nanomolar,853325,=,1,1,=,,IC50,nM,,3500.0,CHEMBL6110,Schistosoma mansoni,Thioredoxin glutathione reductase,6183,,,IC50,uM,UO_0000065,,3.5
# ,,2931450,[],CHEMBL1048278,Inhibition of Schistosoma mansoni TGR,B,,,BAO_0000190,BAO_0000357,single protein format,N#Cc1c(C(=O)c2cccs2)no[n+]1[O-],,,CHEMBL1155233,J Med Chem,2009,"{'bei': '32.55', 'le': '0.66', 'lle': '6.73', 'sei': '7.67'}",,CHEMBL576265,,CHEMBL576265,7.20,0,http://www.openphacts.org/units/Nanomolar,853307,=,1,1,=,,IC50,nM,,63.0,CHEMBL6110,Schistosoma mansoni,Thioredoxin glutathione reductase,6183,,,IC50,uM,UO_0000065,,0.063
# ,,2931451,[],CHEMBL1048278,Inhibition of Schistosoma mansoni TGR,B,,,BAO_0000190,BAO_0000357,single protein format,N#Cc1c(-c2cccs2)no[n+]1[O-],,,CHEMBL1155233,J Med Chem,2009,"{'bei': '28.24', 'le': '0.57', 'lle': '4.55', 'sei': '7.11'}",,CHEMBL583780,,CHEMBL583780,5.46,0,http://www.openphacts.org/units/Nanomolar,853289,=,1,1,=,,IC50,nM,,3500.0,CHEMBL6110,Schistosoma mansoni,Thioredoxin glutathione reductase,6183,,,IC50,uM,UO_0000065,,3.5
# ,,2931452,[],CHEMBL1048278,Inhibition of Schistosoma mansoni TGR,B,,,BAO_0000190,BAO_0000357,single protein format,N#Cc1c(-c2ccco2)no[n+]1[O-],,,CHEMBL1155233,J Med Chem,2009,"{'bei': '31.35', 'le': '0.58', 'lle': '5.11', 'sei': '6.18'}",,CHEMBL565242,,CHEMBL565242,5.55,0,http://www.openphacts.org/units/Nanomolar,853288,=,1,1,=,,IC50,nM,,2800.0,CHEMBL6110,Schistosoma mansoni,Thioredoxin glutathione reductase,6183,,,IC50,uM,UO_0000065,,2.8
# ,,2931453,[],CHEMBL1048278,Inhibition of Schistosoma mansoni TGR,B,,,BAO_0000190,BAO_0000357,single protein format,N#Cc1c(-c2ccc(O)cc2)no[n+]1[O-],,,CHEMBL1155233,J Med Chem,2009,"{'bei': '23.37', 'le': '0.43', 'lle': '4.20', 'sei': '4.89'}",,CHEMBL570132,,CHEMBL570132,4.75,0,http://www.openphacts.org/units/Nanomolar,853274,=,1,1,=,,IC50,nM,,17900.0,CHEMBL6110,Schistosoma mansoni,Thioredoxin glutathione reductase,6183,,,IC50,uM,UO_0000065,,17.9

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                           action_type activity_comment  \
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3                                                None             None
# 4                                                None             None
# 5                                                None             None
# 6                                                None             None
# 7                                                None             None
# 8                                                None             None
# 9                                                None             None
# 10                                               None             None
# 11                                               None             None
# 12                                               None             None
# 13                                               None             None
# 14                                               None             None
# 15                                               None             None
# 16                                               None             None
# 17                                               None             None
# 18                                               None             None
# 19                                               None             None
# 20                                               None             None
# 21                                               None             None
# 22                                               None             None
# 23                                               None             None
# 24                                               None             None
# 25                                               None             None
# 26                                               None             None
# 27                                               None             None
# 28                                               None             None
# 29                                               None             None
# 30                                               None             None
# 31                                               None             None
# 32                                               None             None
# 33                                               None             None
# 34                                               None             None
# 35                                               None             None
# 36                                               None             None
# 37                                               None             None
# 38                                               None             None
# 39                                               None             None
# 40                                               None             None
# 41                                               None             None
# 42                                               None             None
# 43                                               None             None
# 44                                               None             None
# 46                                               None             None
# 47                                               None             None
# 48                                               None             None
# 49  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 50  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 51  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 52  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 53  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 54  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 55  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 56  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 57  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 58  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#     activity_id                                activity_properties  \
# 0       2931445                                                 []
# 1       2931446                                                 []
# 2       2931447                                                 []
# 3       2931448                                                 []
# 4       2931449                                                 []
# 5       2931450                                                 []
# 6       2931451                                                 []
# 7       2931452                                                 []
# 8       2931453                                                 []
# 9       2931454                                                 []
# 10      2931455                                                 []
# 11      2931456                                                 []
# 12      2931457                                                 []
# 13      2931458                                                 []
# 14      2931459                                                 []
# 15      2931460                                                 []
# 16      2931461                                                 []
# 17      2931462                                                 []
# 18      2931463                                                 []
# 19      2931464                                                 []
# 20      2931465                                                 []
# 21      2931466                                                 []
# 22      2931467                                                 []
# 23      2931468                                                 []
# 24      2931469                                                 []
# 25      2931470                                                 []
# 26      2931471                                                 []
# 27      2931472                                                 []
# 28      2931473                                                 []
# 29      2931474                                                 []
# 30      2931475                                                 []
# 31      2931476                                                 []
# 32     15025032                                                 []
# 33     15025033                                                 []
# 34     15025034                                                 []
# 35     15025035                                                 []
# 36     15025036                                                 []
# 37     15025037                                                 []
# 38     15025038                                                 []
# 39     15025039                                                 []
# 40     15025040                                                 []
# 41     15025041                                                 []
# 42     15025042                                                 []
# 43     15025043                                                 []
# 44     15025044                                                 []
# 46     19408408                                                 []
# 47     19408460                                                 []
# 48     19408461                                                 []
# 49     23155571  [{'comments': None, 'relation': '=', 'result_f...
# 50     23155585  [{'comments': None, 'relation': '=', 'result_f...
# 51     23155586  [{'comments': None, 'relation': '=', 'result_f...
# 52     23155587  [{'comments': None, 'relation': '=', 'result_f...
# 53     23155588  [{'comments': None, 'relation': '=', 'result_f...
# 54     23155589  [{'comments': None, 'relation': '=', 'result_f...
# 55     23155590  [{'comments': None, 'relation': '=', 'result_f...
# 56     23155591  [{'comments': None, 'relation': '=', 'result_f...
# 57     26129652  [{'comments': None, 'relation': '=', 'result_f...
# 58     26129653  [{'comments': None, 'relation': '=', 'result_f...
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 1    CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 2    CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 3    CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 4    CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 5    CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 6    CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 7    CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 8    CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 9    CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 10   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 11   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 12   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 13   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 14   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 15   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 16   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 17   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 18   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 19   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 20   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 21   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 22   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 23   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 24   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 25   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 26   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 27   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 28   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 29   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 30   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 31   CHEMBL1048278              Inhibition of Schistosoma mansoni TGR
# 32   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 33   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 34   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 35   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 36   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 37   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 38   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 39   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 40   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 41   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 42   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 43   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 44   CHEMBL3365309  Inhibition of Schistosoma mansoni recombinant ...
# 46   CHEMBL4427075              Inhibition of Schistosoma mansoni TGR
# 47   CHEMBL4427075              Inhibition of Schistosoma mansoni TGR
# 48   CHEMBL4427075              Inhibition of Schistosoma mansoni TGR
# 49   CHEMBL4811507  Inhibition of Schistosoma mansoni thioredoxin ...
# 50   CHEMBL4811511  Inhibition of Schistosoma mansoni thioredoxin ...
# 51   CHEMBL4811511  Inhibition of Schistosoma mansoni thioredoxin ...
# 52   CHEMBL4811511  Inhibition of Schistosoma mansoni thioredoxin ...
# 53   CHEMBL4811511  Inhibition of Schistosoma mansoni thioredoxin ...
# 54   CHEMBL4811511  Inhibition of Schistosoma mansoni thioredoxin ...
# 55   CHEMBL4811511  Inhibition of Schistosoma mansoni thioredoxin ...
# 56   CHEMBL4811511  Inhibition of Schistosoma mansoni thioredoxin ...
# 57   CHEMBL5617298  Inhibition of Schistosoma mansoni TGR incubate...
# 58   CHEMBL5617298  Inhibition of Schistosoma mansoni TGR incubate...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# 5           B                    None                   None  BAO_0000190
# 6           B                    None                   None  BAO_0000190
# 7           B                    None                   None  BAO_0000190
# 8           B                    None                   None  BAO_0000190
# 9           B                    None                   None  BAO_0000190
# 10          B                    None                   None  BAO_0000190
# 11          B                    None                   None  BAO_0000190
# 12          B                    None                   None  BAO_0000190
# 13          B                    None                   None  BAO_0000190
# 14          B                    None                   None  BAO_0000190
# 15          B                    None                   None  BAO_0000190
# 16          B                    None                   None  BAO_0000190
# 17          B                    None                   None  BAO_0000190
# 18          B                    None                   None  BAO_0000190
# 19          B                    None                   None  BAO_0000190
# 20          B                    None                   None  BAO_0000190
# 21          B                    None                   None  BAO_0000190
# 22          B                    None                   None  BAO_0000190
# 23          B                    None                   None  BAO_0000190
# 24          B                    None                   None  BAO_0000190
# 25          B                    None                   None  BAO_0000190
# 26          B                    None                   None  BAO_0000190
# 27          B                    None                   None  BAO_0000190
# 28          B                    None                   None  BAO_0000190
# 29          B                    None                   None  BAO_0000190
# 30          B                    None                   None  BAO_0000190
# 31          B                    None                   None  BAO_0000190
# 32          B                    None                   None  BAO_0000190
# 33          B                    None                   None  BAO_0000190
# 34          B                    None                   None  BAO_0000190
# 35          B                    None                   None  BAO_0000190
# 36          B                    None                   None  BAO_0000190
# 37          B                    None                   None  BAO_0000190
# 38          B                    None                   None  BAO_0000190
# 39          B                    None                   None  BAO_0000190
# 40          B                    None                   None  BAO_0000190
# 41          B                    None                   None  BAO_0000190
# 42          B                    None                   None  BAO_0000190
# 43          B                    None                   None  BAO_0000190
# 44          B                    None                   None  BAO_0000190
# 46          B                    None                   None  BAO_0000190
# 47          B                    None                   None  BAO_0000190
# 48          B                    None                   None  BAO_0000190
# 49          B                    None                   None  BAO_0000190
# 50          B                    None                   None  BAO_0000190
# 51          B                    None                   None  BAO_0000190
# 52          B                    None                   None  BAO_0000190
# 53          B                    None                   None  BAO_0000190
# 54          B                    None                   None  BAO_0000190
# 55          B                    None                   None  BAO_0000190
# 56          B                    None                   None  BAO_0000190
# 57          B                    None                   None  BAO_0000190
# 58          B                    None                   None  BAO_0000190
#
#     ...      target_organism                   target_pref_name target_tax_id  \
# 0   ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 1   ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 2   ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 3   ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 4   ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 5   ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 6   ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 7   ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 8   ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 9   ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 10  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 11  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 12  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 13  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 14  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 15  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 16  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 17  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 18  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 19  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 20  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 21  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 22  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 23  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 24  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 25  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 26  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 27  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 28  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 29  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 30  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 31  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 32  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 33  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 34  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 35  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 36  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 37  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 38  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 39  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 40  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 41  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 42  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 43  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 44  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 46  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 47  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 48  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 49  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 50  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 51  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 52  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 53  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 54  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 55  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 56  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 57  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
# 58  ...  Schistosoma mansoni  Thioredoxin glutathione reductase          6183
#
#    text_value  toid  type units    uo_units upper_value  value
# 0        None  None  IC50    uM  UO_0000065        None   0.35
# 1        None  None  IC50    uM  UO_0000065        None    0.4
# 2        None  None  IC50    uM  UO_0000065        None   0.48
# 3        None  None  IC50    uM  UO_0000065        None    1.0
# 4        None  None  IC50    uM  UO_0000065        None    3.5
# 5        None  None  IC50    uM  UO_0000065        None  0.063
# 6        None  None  IC50    uM  UO_0000065        None    3.5
# 7        None  None  IC50    uM  UO_0000065        None    2.8
# 8        None  None  IC50    uM  UO_0000065        None   17.9
# 9        None  None  IC50    uM  UO_0000065        None   15.8
# 10       None  None  IC50    uM  UO_0000065        None   11.2
# 11       None  None  IC50    uM  UO_0000065        None   10.0
# 12       None  None  IC50    uM  UO_0000065        None    8.9
# 13       None  None  IC50    uM  UO_0000065        None    8.9
# 14       None  None  IC50    uM  UO_0000065        None    7.9
# 15       None  None  IC50    uM  UO_0000065        None    7.9
# 16       None  None  IC50    uM  UO_0000065        None    7.1
# 17       None  None  IC50    uM  UO_0000065        None    7.1
# 18       None  None  IC50    uM  UO_0000065        None    4.0
# 19       None  None  IC50    uM  UO_0000065        None    3.5
# 20       None  None  IC50    uM  UO_0000065        None    3.5
# 21       None  None  IC50    uM  UO_0000065        None    2.8
# 22       None  None  IC50    uM  UO_0000065        None    2.8
# 23       None  None  IC50    uM  UO_0000065        None    2.5
# 24       None  None  IC50    uM  UO_0000065        None    2.2
# 25       None  None  IC50    uM  UO_0000065        None   0.04
# 26       None  None  IC50    uM  UO_0000065        None   17.8
# 27       None  None  IC50    uM  UO_0000065        None   0.63
# 28       None  None  IC50    uM  UO_0000065        None   0.11
# 29       None  None  IC50    uM  UO_0000065        None   11.2
# 30       None  None  IC50    uM  UO_0000065        None   50.0
# 31       None  None  IC50    uM  UO_0000065        None    6.3
# 32       None  None  IC50    uM  UO_0000065        None   50.0
# 33       None  None  IC50    uM  UO_0000065        None    8.5
# 34       None  None  IC50    uM  UO_0000065        None   50.0
# 35       None  None  IC50    uM  UO_0000065        None   50.0
# 36       None  None  IC50    uM  UO_0000065        None   0.35
# 37       None  None  IC50    uM  UO_0000065        None  0.083
# 38       None  None  IC50    uM  UO_0000065        None   50.0
# 39       None  None  IC50    uM  UO_0000065        None   50.0
# 40       None  None  IC50    uM  UO_0000065        None   50.0
# 41       None  None  IC50    uM  UO_0000065        None  0.316
# 42       None  None  IC50    uM  UO_0000065        None   0.01
# 43       None  None  IC50    uM  UO_0000065        None  0.148
# 44       None  None  IC50    uM  UO_0000065        None    5.0
# 46       None  None  IC50    uM  UO_0000065        None   15.8
# 47       None  None  IC50    uM  UO_0000065        None    0.1
# 48       None  None  IC50    uM  UO_0000065        None   7.08
# 49       None  None  IC50    uM  UO_0000065        None   3.15
# 50       None  None  IC50    uM  UO_0000065        None   0.33
# 51       None  None  IC50    uM  UO_0000065        None   0.21
# 52       None  None  IC50    uM  UO_0000065        None   2.84
# 53       None  None  IC50    uM  UO_0000065        None   2.01
# 54       None  None  IC50    uM  UO_0000065        None   0.06
# 55       None  None  IC50    uM  UO_0000065        None   0.14
# 56       None  None  IC50    uM  UO_0000065        None   0.13
# 57       None  None  IC50    uM  UO_0000065        None    2.5
# 58       None  None  IC50    uM  UO_0000065        None   57.5
#
# [58 rows x 47 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL576624  N#Cc1c(-c2csc(-c3no[n+]([O-])c3C#N)c2)no[n+]1[O-]
# 1        CHEMBL569420  N#Cc1c(-c2ccc(-c3no[n+]([O-])c3C#N)s2)no[n+]1[O-]
# 2        CHEMBL570121  N#Cc1c(-c2cc(F)cc(-c3no[n+]([O-])c3C#N)c2)no[n...
# 3        CHEMBL582970  N#Cc1c(-c2ccc(-c3no[n+]([O-])c3C#N)cc2)no[n+]1...
# 4        CHEMBL575013  N#Cc1c(-c2cccc(-c3no[n+]([O-])c3C#N)c2)no[n+]1...
# 5        CHEMBL576265                    N#Cc1c(C(=O)c2cccs2)no[n+]1[O-]
# 6        CHEMBL583780                        N#Cc1c(-c2cccs2)no[n+]1[O-]
# 7        CHEMBL565242                        N#Cc1c(-c2ccco2)no[n+]1[O-]
# 8        CHEMBL570132                    N#Cc1c(-c2ccc(O)cc2)no[n+]1[O-]
# 9        CHEMBL576082            N#Cc1c(-c2ccc(-c3ccccc3)cc2)no[n+]1[O-]
# 10       CHEMBL574801                    Cc1ccc(-c2no[n+]([O-])c2C#N)cc1
# 11       CHEMBL578810                   COc1ccc(-c2no[n+]([O-])c2C#N)cc1
# 12       CHEMBL569188                   COc1cccc(-c2no[n+]([O-])c2C#N)c1
# 13       CHEMBL568961             COc1cc(-c2no[n+]([O-])c2C#N)cc(OC)c1OC
# 14       CHEMBL583779                     COc1ccccc1-c1no[n+]([O-])c1C#N
# 15       CHEMBL576118                    N#Cc1c(-c2ccc(F)cc2)no[n+]1[O-]
# 16       CHEMBL571936                    N#Cc1c(-c2cccc(O)c2)no[n+]1[O-]
# 17       CHEMBL571712             N#Cc1c(-c2ccc(C(F)(F)F)cc2)no[n+]1[O-]
# 18       CHEMBL567408                   N#Cc1c(-c2ccc(Cl)cc2)no[n+]1[O-]
# 19       CHEMBL585368                   N#Cc1c(-c2ccc(Br)cc2)no[n+]1[O-]
# 20       CHEMBL570130                   N#Cc1c(-c2cccc(Cl)c2)no[n+]1[O-]
# 21       CHEMBL574579                   N#Cc1c(-c2cccc(Br)c2)no[n+]1[O-]
# 22       CHEMBL585190                N#Cc1c(-c2ccc(F)c(Br)c2)no[n+]1[O-]
# 23       CHEMBL571710             N#Cc1c(-c2cccc(C(F)(F)F)c2)no[n+]1[O-]
# 24       CHEMBL570346         N#Cc1c(-c2cccc([N+](=O)[O-])c2)no[n+]1[O-]
# 25       CHEMBL570345           O=C(c1cccs1)c1no[n+]([O-])c1C(=O)c1cccs1
# 26       CHEMBL500868                    NC(=O)c1c(-c2ccccc2)no[n+]1[O-]
# 27       CHEMBL574577                    O=C(O)c1c(-c2ccccc2)no[n+]1[O-]
# 28       CHEMBL567637                       O=Cc1c(-c2ccccc2)no[n+]1[O-]
# 29       CHEMBL567641                        [O-][n+]1onc(-c2ccccc2)c1CO
# 30       CHEMBL574360                         Cc1c(-c2ccccc2)no[n+]1[O-]
# 31       CHEMBL336467                       N#Cc1c(-c2ccccc2)no[n+]1[O-]
# 32      CHEMBL3322357  O=C(C1CCCCC1)N1CC(=O)N2CCc3ccc(OCCCOc4nonc4S(=...
# 33      CHEMBL3322356  O=C(C1CCCCC1)N1CC(=O)N2CCc3ccc(OCCCOc4no[n+]([...
# 34      CHEMBL3322355  N#Cc1nonc1COc1ccc2c(c1)C1CN(C(=O)C3CCCCC3)CC(=...
# 35      CHEMBL3322294  NC(=O)c1nonc1COc1ccc2c(c1)C1CN(C(=O)C3CCCCC3)C...
# 36      CHEMBL3322293  N#Cc1c(COc2ccc3c(c2)C2CN(C(=O)C4CCCCC4)CC(=O)N...
# 37      CHEMBL3322292  NC(=O)c1c(COc2ccc3c(c2)C2CN(C(=O)C4CCCCC4)CC(=...
# 38      CHEMBL3322291            N#Cc1nonc1C(=O)N1CC(=O)N2CCc3ccccc3C2C1
# 39      CHEMBL3322290         NC(=O)c1nonc1C(=O)N1CC(=O)N2CCc3ccccc3C2C1
# 40      CHEMBL3322289        COC(=O)c1nonc1C(=O)N1CC(=O)N2CCc3ccccc3C2C1
# 41      CHEMBL3322288   N#Cc1c(C(=O)N2CC(=O)N3CCc4ccccc4C3C2)no[n+]1[O-]
# 42      CHEMBL3322287  NC(=O)c1c(C(=O)N2CC(=O)N3CCc4ccccc4C3C2)no[n+]...
# 43      CHEMBL3322286  COC(=O)c1c(C(=O)N2CC(=O)N3CCc4ccccc4C3C2)no[n+...
# 44       CHEMBL336467                       N#Cc1c(-c2ccccc2)no[n+]1[O-]
# 45      CHEMBL1455957   CCc1nc2c([nH]1)c1no[n+]([O-])c1c1no[n+]([O-])c21
# 46      CHEMBL1325877  COc1ccc(C(=O)c2no[n+]([O-])c2C(=O)c2ccc(OC)cc2...
# 47      CHEMBL1449349                O=C(CSc1ccccn1)Nc1nonc1[N+](=O)[O-]
# 48      CHEMBL4871407           CCNc1sc(Br)c([N+](=O)[O-])c1[N+](=O)[O-]
# 49      CHEMBL4852477  COC(=O)CS(=O)(=O)c1nnc(C(Cc2ccccc2)NC(=O)OC(C)...
# 50      CHEMBL1428415  CCN(c1ccccc1)S(=O)(=O)c1ccc(NC(=O)c2nc(S(C)(=O...
# 51      CHEMBL4858362              O=c1c(Cl)c(-n2cc(CO)nn2)cnn1-c1ccccc1
# 52      CHEMBL1337170               O=[N+]([O-])c1ccc2c(c1)S(=O)(=O)C=C2
# 53      CHEMBL1439384    COc1ccc([N+](=O)[O-])c(S(=O)(=O)c2ccc(Cl)cc2)n1
# 54      CHEMBL4846043  CCOC(=O)C(C(=O)OCC)C1=C(Br)C2=NOC3c4ccccc4C(=O...
# 55      CHEMBL1486739      COc1ccc(C(Nc2cc(C)ccn2)c2ccc3ccc(C)nc3c2O)cc1
# 56      CHEMBL5618241  C#CCN(Cc1nc(-c2ccccc2)oc1C)C1C[C@@H]2C[C@H]([C...
# 57      CHEMBL5619580  C[C@@H]1[C@H]2C[C@@H](C[C@H]1NCc1cn([C@@H]3OC[...
#
#    bioactivity_class standard_value
# 0             active          350.0
# 1             active          400.0
# 2             active          480.0
# 3             active         1000.0
# 4       intermediate         3500.0
# 5             active           63.0
# 6       intermediate         3500.0
# 7       intermediate         2800.0
# 8           inactive        17900.0
# 9           inactive        15800.0
# 10          inactive        11200.0
# 11          inactive        10000.0
# 12      intermediate         8900.0
# 13      intermediate         8900.0
# 14      intermediate         7900.0
# 15      intermediate         7900.0
# 16      intermediate         7100.0
# 17      intermediate         7100.0
# 18      intermediate         4000.0
# 19      intermediate         3500.0
# 20      intermediate         3500.0
# 21      intermediate         2800.0
# 22      intermediate         2800.0
# 23      intermediate         2500.0
# 24      intermediate         2200.0
# 25            active           40.0
# 26          inactive        17800.0
# 27            active          630.0
# 28            active          110.0
# 29          inactive        11200.0
# 30          inactive        50000.0
# 31      intermediate         6300.0
# 32          inactive        50000.0
# 33      intermediate         8500.0
# 34          inactive        50000.0
# 35          inactive        50000.0
# 36            active          350.0
# 37            active           83.0
# 38          inactive        50000.0
# 39          inactive        50000.0
# 40          inactive        50000.0
# 41            active          316.0
# 42            active           10.0
# 43            active          148.0
# 44      intermediate         5000.0
# 45          inactive        15800.0
# 46            active          100.0
# 47      intermediate         7080.0
# 48      intermediate         3150.0
# 49            active          330.0
# 50            active          210.0
# 51      intermediate         2840.0
# 52      intermediate         2010.0
# 53            active           60.0
# 54            active          140.0
# 55            active          130.0
# 56      intermediate         2500.0
# 57          inactive        57500.0

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL576624  N#Cc1c(-c2csc(-c3no[n+]([O-])c3C#N)c2)no[n+]1[O-]
# 1        CHEMBL569420  N#Cc1c(-c2ccc(-c3no[n+]([O-])c3C#N)s2)no[n+]1[O-]
# 2        CHEMBL570121  N#Cc1c(-c2cc(F)cc(-c3no[n+]([O-])c3C#N)c2)no[n...
# 3        CHEMBL582970  N#Cc1c(-c2ccc(-c3no[n+]([O-])c3C#N)cc2)no[n+]1...
# 4        CHEMBL575013  N#Cc1c(-c2cccc(-c3no[n+]([O-])c3C#N)c2)no[n+]1...
# 5        CHEMBL576265                    N#Cc1c(C(=O)c2cccs2)no[n+]1[O-]
# 6        CHEMBL583780                        N#Cc1c(-c2cccs2)no[n+]1[O-]
# 7        CHEMBL565242                        N#Cc1c(-c2ccco2)no[n+]1[O-]
# 8        CHEMBL570132                    N#Cc1c(-c2ccc(O)cc2)no[n+]1[O-]
# 9        CHEMBL576082            N#Cc1c(-c2ccc(-c3ccccc3)cc2)no[n+]1[O-]
# 10       CHEMBL574801                    Cc1ccc(-c2no[n+]([O-])c2C#N)cc1
# 11       CHEMBL578810                   COc1ccc(-c2no[n+]([O-])c2C#N)cc1
# 12       CHEMBL569188                   COc1cccc(-c2no[n+]([O-])c2C#N)c1
# 13       CHEMBL568961             COc1cc(-c2no[n+]([O-])c2C#N)cc(OC)c1OC
# 14       CHEMBL583779                     COc1ccccc1-c1no[n+]([O-])c1C#N
# 15       CHEMBL576118                    N#Cc1c(-c2ccc(F)cc2)no[n+]1[O-]
# 16       CHEMBL571936                    N#Cc1c(-c2cccc(O)c2)no[n+]1[O-]
# 17       CHEMBL571712             N#Cc1c(-c2ccc(C(F)(F)F)cc2)no[n+]1[O-]
# 18       CHEMBL567408                   N#Cc1c(-c2ccc(Cl)cc2)no[n+]1[O-]
# 19       CHEMBL585368                   N#Cc1c(-c2ccc(Br)cc2)no[n+]1[O-]
# 20       CHEMBL570130                   N#Cc1c(-c2cccc(Cl)c2)no[n+]1[O-]
# 21       CHEMBL574579                   N#Cc1c(-c2cccc(Br)c2)no[n+]1[O-]
# 22       CHEMBL585190                N#Cc1c(-c2ccc(F)c(Br)c2)no[n+]1[O-]
# 23       CHEMBL571710             N#Cc1c(-c2cccc(C(F)(F)F)c2)no[n+]1[O-]
# 24       CHEMBL570346         N#Cc1c(-c2cccc([N+](=O)[O-])c2)no[n+]1[O-]
# 25       CHEMBL570345           O=C(c1cccs1)c1no[n+]([O-])c1C(=O)c1cccs1
# 26       CHEMBL500868                    NC(=O)c1c(-c2ccccc2)no[n+]1[O-]
# 27       CHEMBL574577                    O=C(O)c1c(-c2ccccc2)no[n+]1[O-]
# 28       CHEMBL567637                       O=Cc1c(-c2ccccc2)no[n+]1[O-]
# 29       CHEMBL567641                        [O-][n+]1onc(-c2ccccc2)c1CO
# 30       CHEMBL574360                         Cc1c(-c2ccccc2)no[n+]1[O-]
# 31       CHEMBL336467                       N#Cc1c(-c2ccccc2)no[n+]1[O-]
# 32      CHEMBL3322357  O=C(C1CCCCC1)N1CC(=O)N2CCc3ccc(OCCCOc4nonc4S(=...
# 33      CHEMBL3322356  O=C(C1CCCCC1)N1CC(=O)N2CCc3ccc(OCCCOc4no[n+]([...
# 34      CHEMBL3322355  N#Cc1nonc1COc1ccc2c(c1)C1CN(C(=O)C3CCCCC3)CC(=...
# 35      CHEMBL3322294  NC(=O)c1nonc1COc1ccc2c(c1)C1CN(C(=O)C3CCCCC3)C...
# 36      CHEMBL3322293  N#Cc1c(COc2ccc3c(c2)C2CN(C(=O)C4CCCCC4)CC(=O)N...
# 37      CHEMBL3322292  NC(=O)c1c(COc2ccc3c(c2)C2CN(C(=O)C4CCCCC4)CC(=...
# 38      CHEMBL3322291            N#Cc1nonc1C(=O)N1CC(=O)N2CCc3ccccc3C2C1
# 39      CHEMBL3322290         NC(=O)c1nonc1C(=O)N1CC(=O)N2CCc3ccccc3C2C1
# 40      CHEMBL3322289        COC(=O)c1nonc1C(=O)N1CC(=O)N2CCc3ccccc3C2C1
# 41      CHEMBL3322288   N#Cc1c(C(=O)N2CC(=O)N3CCc4ccccc4C3C2)no[n+]1[O-]
# 42      CHEMBL3322287  NC(=O)c1c(C(=O)N2CC(=O)N3CCc4ccccc4C3C2)no[n+]...
# 43      CHEMBL3322286  COC(=O)c1c(C(=O)N2CC(=O)N3CCc4ccccc4C3C2)no[n+...
# 44       CHEMBL336467                       N#Cc1c(-c2ccccc2)no[n+]1[O-]
# 46      CHEMBL1455957   CCc1nc2c([nH]1)c1no[n+]([O-])c1c1no[n+]([O-])c21
# 47      CHEMBL1325877  COc1ccc(C(=O)c2no[n+]([O-])c2C(=O)c2ccc(OC)cc2...
# 48      CHEMBL1449349                O=C(CSc1ccccn1)Nc1nonc1[N+](=O)[O-]
# 49      CHEMBL4871407           CCNc1sc(Br)c([N+](=O)[O-])c1[N+](=O)[O-]
# 50      CHEMBL4852477  COC(=O)CS(=O)(=O)c1nnc(C(Cc2ccccc2)NC(=O)OC(C)...
# 51      CHEMBL1428415  CCN(c1ccccc1)S(=O)(=O)c1ccc(NC(=O)c2nc(S(C)(=O...
# 52      CHEMBL4858362              O=c1c(Cl)c(-n2cc(CO)nn2)cnn1-c1ccccc1
# 53      CHEMBL1337170               O=[N+]([O-])c1ccc2c(c1)S(=O)(=O)C=C2
# 54      CHEMBL1439384    COc1ccc([N+](=O)[O-])c(S(=O)(=O)c2ccc(Cl)cc2)n1
# 55      CHEMBL4846043  CCOC(=O)C(C(=O)OCC)C1=C(Br)C2=NOC3c4ccccc4C(=O...
# 56      CHEMBL1486739      COc1ccc(C(Nc2cc(C)ccn2)c2ccc3ccc(C)nc3c2O)cc1
# 57      CHEMBL5618241  C#CCN(Cc1nc(-c2ccccc2)oc1C)C1C[C@@H]2C[C@H]([C...
# 58      CHEMBL5619580  C[C@@H]1[C@H]2C[C@@H](C[C@H]1NCc1cn([C@@H]3OC[...
#
#    standard_value
# 0           350.0
# 1           400.0
# 2           480.0
# 3          1000.0
# 4          3500.0
# 5            63.0
# 6          3500.0
# 7          2800.0
# 8         17900.0
# 9         15800.0
# 10        11200.0
# 11        10000.0
# 12         8900.0
# 13         8900.0
# 14         7900.0
# 15         7900.0
# 16         7100.0
# 17         7100.0
# 18         4000.0
# 19         3500.0
# 20         3500.0
# 21         2800.0
# 22         2800.0
# 23         2500.0
# 24         2200.0
# 25           40.0
# 26        17800.0
# 27          630.0
# 28          110.0
# 29        11200.0
# 30        50000.0
# 31         6300.0
# 32        50000.0
# 33         8500.0
# 34        50000.0
# 35        50000.0
# 36          350.0
# 37           83.0
# 38        50000.0
# 39        50000.0
# 40        50000.0
# 41          316.0
# 42           10.0
# 43          148.0
# 44         5000.0
# 46        15800.0
# 47          100.0
# 48         7080.0
# 49         3150.0
# 50          330.0
# 51          210.0
# 52         2840.0
# 53         2010.0
# 54           60.0
# 55          140.0
# 56          130.0
# 57         2500.0
# 58        57500.0

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL576624  N#Cc1c(-c2csc(-c3no[n+]([O-])c3C#N)c2)no[n+]1[O-]
# 1        CHEMBL569420  N#Cc1c(-c2ccc(-c3no[n+]([O-])c3C#N)s2)no[n+]1[O-]
# 2        CHEMBL570121  N#Cc1c(-c2cc(F)cc(-c3no[n+]([O-])c3C#N)c2)no[n...
# 3        CHEMBL582970  N#Cc1c(-c2ccc(-c3no[n+]([O-])c3C#N)cc2)no[n+]1...
# 4        CHEMBL575013  N#Cc1c(-c2cccc(-c3no[n+]([O-])c3C#N)c2)no[n+]1...
# 5        CHEMBL576265                    N#Cc1c(C(=O)c2cccs2)no[n+]1[O-]
# 6        CHEMBL583780                        N#Cc1c(-c2cccs2)no[n+]1[O-]
# 7        CHEMBL565242                        N#Cc1c(-c2ccco2)no[n+]1[O-]
# 8        CHEMBL570132                    N#Cc1c(-c2ccc(O)cc2)no[n+]1[O-]
# 9        CHEMBL576082            N#Cc1c(-c2ccc(-c3ccccc3)cc2)no[n+]1[O-]
# 10       CHEMBL574801                    Cc1ccc(-c2no[n+]([O-])c2C#N)cc1
# 11       CHEMBL578810                   COc1ccc(-c2no[n+]([O-])c2C#N)cc1
# 12       CHEMBL569188                   COc1cccc(-c2no[n+]([O-])c2C#N)c1
# 13       CHEMBL568961             COc1cc(-c2no[n+]([O-])c2C#N)cc(OC)c1OC
# 14       CHEMBL583779                     COc1ccccc1-c1no[n+]([O-])c1C#N
# 15       CHEMBL576118                    N#Cc1c(-c2ccc(F)cc2)no[n+]1[O-]
# 16       CHEMBL571936                    N#Cc1c(-c2cccc(O)c2)no[n+]1[O-]
# 17       CHEMBL571712             N#Cc1c(-c2ccc(C(F)(F)F)cc2)no[n+]1[O-]
# 18       CHEMBL567408                   N#Cc1c(-c2ccc(Cl)cc2)no[n+]1[O-]
# 19       CHEMBL585368                   N#Cc1c(-c2ccc(Br)cc2)no[n+]1[O-]
# 20       CHEMBL570130                   N#Cc1c(-c2cccc(Cl)c2)no[n+]1[O-]
# 21       CHEMBL574579                   N#Cc1c(-c2cccc(Br)c2)no[n+]1[O-]
# 22       CHEMBL585190                N#Cc1c(-c2ccc(F)c(Br)c2)no[n+]1[O-]
# 23       CHEMBL571710             N#Cc1c(-c2cccc(C(F)(F)F)c2)no[n+]1[O-]
# 24       CHEMBL570346         N#Cc1c(-c2cccc([N+](=O)[O-])c2)no[n+]1[O-]
# 25       CHEMBL570345           O=C(c1cccs1)c1no[n+]([O-])c1C(=O)c1cccs1
# 26       CHEMBL500868                    NC(=O)c1c(-c2ccccc2)no[n+]1[O-]
# 27       CHEMBL574577                    O=C(O)c1c(-c2ccccc2)no[n+]1[O-]
# 28       CHEMBL567637                       O=Cc1c(-c2ccccc2)no[n+]1[O-]
# 29       CHEMBL567641                        [O-][n+]1onc(-c2ccccc2)c1CO
# 30       CHEMBL574360                         Cc1c(-c2ccccc2)no[n+]1[O-]
# 31       CHEMBL336467                       N#Cc1c(-c2ccccc2)no[n+]1[O-]
# 32      CHEMBL3322357  O=C(C1CCCCC1)N1CC(=O)N2CCc3ccc(OCCCOc4nonc4S(=...
# 33      CHEMBL3322356  O=C(C1CCCCC1)N1CC(=O)N2CCc3ccc(OCCCOc4no[n+]([...
# 34      CHEMBL3322355  N#Cc1nonc1COc1ccc2c(c1)C1CN(C(=O)C3CCCCC3)CC(=...
# 35      CHEMBL3322294  NC(=O)c1nonc1COc1ccc2c(c1)C1CN(C(=O)C3CCCCC3)C...
# 36      CHEMBL3322293  N#Cc1c(COc2ccc3c(c2)C2CN(C(=O)C4CCCCC4)CC(=O)N...
# 37      CHEMBL3322292  NC(=O)c1c(COc2ccc3c(c2)C2CN(C(=O)C4CCCCC4)CC(=...
# 38      CHEMBL3322291            N#Cc1nonc1C(=O)N1CC(=O)N2CCc3ccccc3C2C1
# 39      CHEMBL3322290         NC(=O)c1nonc1C(=O)N1CC(=O)N2CCc3ccccc3C2C1
# 40      CHEMBL3322289        COC(=O)c1nonc1C(=O)N1CC(=O)N2CCc3ccccc3C2C1
# 41      CHEMBL3322288   N#Cc1c(C(=O)N2CC(=O)N3CCc4ccccc4C3C2)no[n+]1[O-]
# 42      CHEMBL3322287  NC(=O)c1c(C(=O)N2CC(=O)N3CCc4ccccc4C3C2)no[n+]...
# 43      CHEMBL3322286  COC(=O)c1c(C(=O)N2CC(=O)N3CCc4ccccc4C3C2)no[n+...
# 44       CHEMBL336467                       N#Cc1c(-c2ccccc2)no[n+]1[O-]
# 46      CHEMBL1455957   CCc1nc2c([nH]1)c1no[n+]([O-])c1c1no[n+]([O-])c21
# 47      CHEMBL1325877  COc1ccc(C(=O)c2no[n+]([O-])c2C(=O)c2ccc(OC)cc2...
# 48      CHEMBL1449349                O=C(CSc1ccccn1)Nc1nonc1[N+](=O)[O-]
# 49      CHEMBL4871407           CCNc1sc(Br)c([N+](=O)[O-])c1[N+](=O)[O-]
# 50      CHEMBL4852477  COC(=O)CS(=O)(=O)c1nnc(C(Cc2ccccc2)NC(=O)OC(C)...
# 51      CHEMBL1428415  CCN(c1ccccc1)S(=O)(=O)c1ccc(NC(=O)c2nc(S(C)(=O...
# 52      CHEMBL4858362              O=c1c(Cl)c(-n2cc(CO)nn2)cnn1-c1ccccc1
# 53      CHEMBL1337170               O=[N+]([O-])c1ccc2c(c1)S(=O)(=O)C=C2
# 54      CHEMBL1439384    COc1ccc([N+](=O)[O-])c(S(=O)(=O)c2ccc(Cl)cc2)n1
# 55      CHEMBL4846043  CCOC(=O)C(C(=O)OCC)C1=C(Br)C2=NOC3c4ccccc4C(=O...
# 56      CHEMBL1486739      COc1ccc(C(Nc2cc(C)ccn2)c2ccc3ccc(C)nc3c2O)cc1
# 57      CHEMBL5618241  C#CCN(Cc1nc(-c2ccccc2)oc1C)C1C[C@@H]2C[C@H]([C...
# 58      CHEMBL5619580  C[C@@H]1[C@H]2C[C@@H](C[C@H]1NCc1cn([C@@H]3OC[...
# 45                NaN                                                NaN
#
#    standard_value             0
# 0           350.0        active
# 1           400.0        active
# 2           480.0        active
# 3          1000.0        active
# 4          3500.0  intermediate
# 5            63.0        active
# 6          3500.0  intermediate
# 7          2800.0  intermediate
# 8         17900.0      inactive
# 9         15800.0      inactive
# 10        11200.0      inactive
# 11        10000.0      inactive
# 12         8900.0  intermediate
# 13         8900.0  intermediate
# 14         7900.0  intermediate
# 15         7900.0  intermediate
# 16         7100.0  intermediate
# 17         7100.0  intermediate
# 18         4000.0  intermediate
# 19         3500.0  intermediate
# 20         3500.0  intermediate
# 21         2800.0  intermediate
# 22         2800.0  intermediate
# 23         2500.0  intermediate
# 24         2200.0  intermediate
# 25           40.0        active
# 26        17800.0      inactive
# 27          630.0        active
# 28          110.0        active
# 29        11200.0      inactive
# 30        50000.0      inactive
# 31         6300.0  intermediate
# 32        50000.0      inactive
# 33         8500.0  intermediate
# 34        50000.0      inactive
# 35        50000.0      inactive
# 36          350.0        active
# 37           83.0        active
# 38        50000.0      inactive
# 39        50000.0      inactive
# 40        50000.0      inactive
# 41          316.0        active
# 42           10.0        active
# 43          148.0        active
# 44         5000.0  intermediate
# 46        15800.0        active
# 47          100.0  intermediate
# 48         7080.0  intermediate
# 49         3150.0        active
# 50          330.0        active
# 51          210.0  intermediate
# 52         2840.0  intermediate
# 53         2010.0        active
# 54           60.0        active
# 55          140.0        active
# 56          130.0  intermediate
# 57         2500.0      inactive
# 58        57500.0           NaN
# 45            NaN      inactive

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 48
# -rw-r--r-- 1 root root 34347 Aug 20 13:48 bioactivity_data.csv
# -rw-r--r-- 1 root root  3744 Aug 20 13:52 bioactivity_preprocessed_data.csv
# drwx------ 5 root root  4096 Aug 20 13:48 gdrive
# drwxr-xr-x 1 root root  4096 Aug 18 13:44 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/data'

# %% [markdown]
# ---
